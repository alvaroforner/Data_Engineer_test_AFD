# %% [markdown]
# <a href="https://colab.research.google.com/github/alvaroforner/Data_Engineer_test_AFD/blob/main/Copia_de_Copia_de_Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import requests

# %%
# Global variables
api =  "https://api.themoviedb.org/3/movie/top_rated?api_key=d73d7e5e4c1dda40808ef100a89f97c1&language=en-US&page=1"
#input_parameter = 278
#api_key = "d73d7e5e4c1dda40808ef100a89f97c1"

#The user is asked to indicate the Airline ID they wish to have on their DB.
#input_parameter = input("Enter an Airline ID: ")
#print(input_parameter)
# Out:
# Enter an Airline ID: 278
# 278

# %%
#The functions are declared

def database_generator(api):
  response = requests.get(api)
  response.json()["results"]
  airlines_db = pd.DataFrame(response.json()['results'])[['id', 'title',\
            'overview', 'popularity', 'release_date', 'vote_average', 'vote_count' ]]
  return airlines_db

def database_writer(airlines_db):
  airlines_db.to_csv('airlines_db.txt', sep=';', index = False, encoding='utf-8')


def buscador_id(api, input_parameter):
  response = requests.get(api)
  response.json()["results"]
  airlines_tmp = pd.DataFrame(response.json()['results'])[['id', 'title',\
            'overview', 'popularity', 'release_date', 'vote_average', 'vote_count' ]]
  fcond1 = airlines_tmp['id'] == input_parameter
  airlines_search = airlines_tmp[fcond1]
  if airlines_search.shape[0] != 0:
    print("Registro localizado en la plataforma de airlines")
    return airlines_search
  else: 
    print("Idnetificador no localizado en la plataforma de airlines. Introduzca otro ID")

# %%
#Check if the DB exists, if not a new DB called Airlines_DB is created.
try:

  df_db = pd.read_csv('airlines_db.txt', sep=";")
  print("Database read successfully. You can proceed with the following steps")

except:
  print("Database not found. A new database is generated.")
  airlines_db = database_generator(api)
  database_writer(airlines_db)
  print("Database successfully generated. Name: Airlines_DB")

airline_reg = buscador_id(api, input_parameter)
# Out:
# Database not found. A new database is generated.
# Database successfully generated. Name: Airlines_DB
# Idnetificador no localizado en la plataforma de airlines. Introduzca otro ID

# %%
def database_generator(api):
  response = requests.get(api)
  response.json()["results"]
  airlines_db = pd.DataFrame(response.json()['results'])[['id', 'title',\
            'overview', 'popularity', 'release_date', 'vote_average', 'vote_count' ]]
  return airlines_db

def database_writer(airlines_db):
  airlines_db.to_csv('airlines_db.txt', sep=';', index = False, encoding='utf-8')


def buscador_id(api, input_parameter):
  response = requests.get(api)
  response.json()["results"]
  airlines_tmp = pd.DataFrame(response.json()['results'])[['id', 'title',\
            'overview', 'popularity', 'release_date', 'vote_average', 'vote_count' ]]
  fcond1 = airlines_tmp['id'] == input_parameter
  airlines_search = airlines_tmp[fcond1]
  if airlines_search.shape[0] != 0:
    print("Registro localizado en la plataforma de airlines")
    return airlines_search
  else: 
    print("Idnetificador no localizado en la plataforma de airlines. Introduzca otro ID")

# %%
for i in range (1, 429):
  response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=d73d7e5e4c1dda40808ef100a89f97c1&language=en-US&page= {}".format(i))
  temp_df = pd.DataFrame(response.json()['results'])[['id', 'title',\
            'overview', 'popularity', 'release_date', 'vote_average', 'vote_count' ]]
  data.append(temp_df, ignore_index = False)

# %%
id = airlines_search.at[0,'id']

# %%
airlines_search
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
#
#                                             overview  popularity release_date  \
# 0  Framed in the 1940s for the double murder of h...       58.86   1994-09-23
#
#    vote_average  vote_count
# 0           8.7       21571

# %%
# chek id in database

def check_id(x, input_parameter):
  if x['id'] == input_parameter:
    res = "T"
  else:
    res = "F"
  return res

df_db['check'] = df_db.apply(lambda x: check_id(x, input_parameter), axis = 'columns')

fcond = df_db['check'] == "F"
df_db = df_db[fcond]
df_db.drop(['check'], axis=1, inplace = True)
df_db
# Out:
#         id                           title  \
# 1    19404     Dilwale Dulhania Le Jayenge
# 2      238                   The Godfather
# 3      424                Schindler's List
# 4      240          The Godfather: Part II
# 5   667257               Impossible Things
# 6   372754        Dou kyu sei – Classmates
# 7      129                   Spirited Away
# 8   372058                      Your Name.
# 9   696374               Gabriel's Inferno
# 10  496243                        Parasite
# 11     389                    12 Angry Men
# 12  730154                  Your Eyes Tell
# 13  533514    Violet Evergarden: The Movie
# 14  724089      Gabriel's Inferno: Part II
# 15     497                  The Green Mile
# 16     155                 The Dark Knight
# 17  761053     Gabriel's Inferno: Part III
# 18     680                    Pulp Fiction
# 19     429  The Good, the Bad and the Ugly
#
#                                              overview  popularity  \
# ...

# %%
fcond = df_db['check'] == "T"
fcond
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: check, dtype: bool
