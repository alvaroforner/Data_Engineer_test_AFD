# %% [markdown]
# <a href="https://colab.research.google.com/github/alvaroforner/Q1_Jeff/blob/main/Q3_API_Jeff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
import requests

api_key = "d73d7e5e4c1dda40808ef100a89f97c1"
link = "https://api.themoviedb.org/3/movie/top_rated?api_key=d73d7e5e4c1dda40808ef100a89f97c1&language=en-US&page=1"
response = requests.get(link)

# %%
response.json()["results"]
# Out:
# [{'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 57.466,
#   'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 21545},
#  {'adult': False,
#   'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'original_language': 'hi',
# ...

# %%
data = pd.DataFrame(response.json()['results'])[['id', 'title',\
            'overview', 'popularity', 'release_date', 'vote_average', 'vote_count' ]] 
data.count()
# Out:
# id              20
# title           20
# overview        20
# popularity      20
# release_date    20
# vote_average    20
# vote_count      20
# dtype: int64

# %%
for i in range (1, 429):
  response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=d73d7e5e4c1dda40808ef100a89f97c1&language=en-US&page= {}".format(i))
  temp_df = pd.DataFrame(response.json()['results'])[['id', 'title',\
            'overview', 'popularity', 'release_date', 'vote_average', 'vote_count' ]]
  data.append(temp_df, ignore_index = False)

# %%
movies_database = data

# %%
movies_database
# Out:
#         id                           title  \
# 0      278        The Shawshank Redemption
# 1    19404     Dilwale Dulhania Le Jayenge
# 2      238                   The Godfather
# 3      424                Schindler's List
# 4      240          The Godfather: Part II
# 5   667257               Impossible Things
# 6   372754        Dou kyu sei – Classmates
# 7      129                   Spirited Away
# 8   372058                      Your Name.
# 9   696374               Gabriel's Inferno
# 10  496243                        Parasite
# 11  724089      Gabriel's Inferno: Part II
# 12     389                    12 Angry Men
# 13     497                  The Green Mile
# 14  533514    Violet Evergarden: The Movie
# 15  730154                  Your Eyes Tell
# 16     155                 The Dark Knight
# 17  761053     Gabriel's Inferno: Part III
# 18     680                    Pulp Fiction
# 19     429  The Good, the Bad and the Ugly
#
# ...

# %%
movie_id = "278"
api_key = "d73d7e5e4c1dda40808ef100a89f97c1"
link = "https://api.themoviedb.org/3/movie/278?api_key=d73d7e5e4c1dda40808ef100a89f97c1&language=en-US"
#.format(movie_id, api_key)
response = requests.get(link)
response.json()
#temp_df = pd.DataFrame(response.json()['results'])[['id', 'title',\
 #           'overview', 'popularity', 'release_date', 'vote_average', 'vote_count' ]]
# Out:
# {'adult': False,
#  'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#  'belongs_to_collection': None,
#  'budget': 25000000,
#  'genres': [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}],
#  'homepage': '',
#  'id': 278,
#  'imdb_id': 'tt0111161',
#  'original_language': 'en',
#  'original_title': 'The Shawshank Redemption',
#  'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#  'popularity': 57.466,
#  'poster_path': '/q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg',
#  'production_companies': [{'id': 97,
#    'logo_path': '/7znWcbDd4PcJzJUlJxYqAlPPykp.png',
#    'name': 'Castle Rock Entertainment',
#    'origin_country': 'US'},
# ...

# %%
link = "https://api.instantwebtools.net/v1/airlines"
#.format(movie_id, api_key)
response = requests.get(link)
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-37-091218eff3cc> in <module>()
#       3 #.format(movie_id, api_key)
#       4 response = requests.get(link)
# ----> 5 response.json()
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# /usr/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ...
